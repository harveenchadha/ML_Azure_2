# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License.

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/NotebookVM/how-to-use-azureml/machine-learning-pipelines/intro-to-pipelines/aml-pipelines-with-automated-machine-learning-step.png)

# %% [markdown]
# # Azure Machine Learning Pipeline with AutoMLStep (Udacity Course 2)
# This notebook demonstrates the use of AutoMLStep in Azure Machine Learning Pipeline.

# %% [markdown]
# ## Introduction
# In this example we showcase how you can use AzureML Dataset to load data for AutoML via AML Pipeline.
#
# If you are using an Azure Machine Learning Notebook VM, you are all set. Otherwise, make sure you have executed the [configuration](https://aka.ms/pl-config) before running this notebook.
#
# In this notebook you will learn how to:
# 1. Create an `Experiment` in an existing `Workspace`.
# 2. Create or Attach existing AmlCompute to a workspace.
# 3. Define data loading in a `TabularDataset`.
# 4. Configure AutoML using `AutoMLConfig`.
# 5. Use AutoMLStep
# 6. Train the model using AmlCompute
# 7. Explore the results.
# 8. Test the best fitted model.

# %% [markdown]
# ## Azure Machine Learning and Pipeline SDK-specific imports

# %%
import logging
import os
import csv

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
import pkg_resources

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.core.dataset import Dataset

from azureml.pipeline.steps import AutoMLStep

# Check core SDK version number
print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.15.0

# %% [markdown]
# ## Initialize Workspace
# Initialize a workspace object from persisted configuration. Make sure the config file is present at .\config.json

# %%
ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# quick-starts-ws-123382
# aml-quickstarts-123382
# southcentralus
# 572f8abf-a1a0-4b78-8c6d-3630739c72b5

# %% [markdown]
# ## Create an Azure ML experiment
# Let's create an experiment named "automlstep-classification" and a folder to hold the training scripts. The script runs will be recorded under the experiment in Azure.
#
# The best practice is to use separate folders for scripts and its dependent files for each step and specify that folder as the `source_directory` for the step. This helps reduce the size of the snapshot created for the step (only the specific folder is snapshotted). Since changes in any files in the `source_directory` would trigger a re-upload of the snapshot, this helps keep the reuse of the step when there are no changes in the `source_directory` of the step.
#
# *Udacity Note:* There is no need to create an Azure ML experiment, this needs to re-use the experiment that was already created

# %%
# Choose a name for the run history container in the workspace.
# NOTE: update these to match your existing experiment name
experiment_name = 'automl'
project_folder = './pipeline-project'

experiment = Experiment(ws, experiment_name)
experiment
# Out:
# Experiment(Name: automl,
# Workspace: quick-starts-ws-123382)

# %% [markdown]
# ### Create or Attach an AmlCompute cluster
# You will need to create a [compute target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) for your AutoML run. In this tutorial, you get the default `AmlCompute` as your training compute resource.
#
# **Udacity Note** There is no need to create a new compute target, it can re-use the previous cluster

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException

# NOTE: update the cluster name to match the existing cluster
# Choose a name for your CPU cluster
amlcompute_cluster_name = "auto-ml"

# Verify that cluster does not exist already
try:
    compute_target = ComputeTarget(workspace=ws, name=amlcompute_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2',# for GPU, use "STANDARD_NC6"
                                                           #vm_priority = 'lowpriority', # optional
                                                           min_nodes=1, max_nodes=4)
    compute_target = ComputeTarget.create(ws, amlcompute_cluster_name, compute_config)

#compute_target.wait_for_completion(show_output=True, min_node_count = 1, timeout_in_minutes = 2)
# For a more detailed view of current AmlCompute status, use get_status().

# %% [markdown]
# ## Data
#
# **Udacity note:** Make sure the `key` is the same name as the dataset that is uploaded, and that the description matches. If it is hard to find or unknown, loop over the `ws.datasets.keys()` and `print()` them.
# If it *isn't* found because it was deleted, it can be recreated with the link that has the CSV

# %%
# Try to load the dataset from the Workspace. Otherwise, create it from the file
# NOTE: update the key to match the dataset name
found = False
key = "BankMarketing Dataset"
description_text = "Bank Marketing DataSet for Udacity Course 2"

if key in ws.datasets.keys(): 
        found = True
        dataset = ws.datasets[key] 

if not found:
        # Create AML Dataset and register it into Workspace
        example_data = 'https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv'
        dataset = Dataset.Tabular.from_delimited_files(example_data)        
        #Register Dataset in Workspace
        dataset = dataset.register(workspace=ws,
                                   name=key,
                                   description=description_text)


df = dataset.to_pandas_dataframe()
df.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  32950.000000  32950.000000  32950.000000  32950.000000  32950.000000
# mean      40.040212    257.335205      2.561730    962.174780      0.174780
# std       10.432313    257.331700      2.763646    187.646785      0.496503
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    179.000000      2.000000    999.000000      0.000000
# 75%       47.000000    318.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  32950.000000    32950.000000   32950.000000  32950.000000  32950.000000
# mean       0.076228       93.574243     -40.518680      3.615654   5166.859608
# std        1.572242        0.578636       4.623004      1.735748     72.208448
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %% [markdown]
# ### Review the Dataset Result
#
# You can peek the result of a TabularDataset at any range using `skip(i)` and `take(j).to_pandas_dataframe()`. Doing so evaluates only `j` records for all the steps in the TabularDataset, which makes it fast even against large datasets.
#
# `TabularDataset` objects are composed of a list of transformation steps (optional).

# %%
dataset.take(5).to_pandas_dataframe()
# Out:
#    age          job  marital    education  default housing loan    contact  \
# 0   57   technician  married  high.school       no      no  yes   cellular
# 1   55      unknown  married      unknown  unknown     yes   no  telephone
# 2   33  blue-collar  married     basic.9y       no      no   no   cellular
# 3   36       admin.  married  high.school       no      no   no  telephone
# 4   27    housemaid  married  high.school       no     yes   no   cellular
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         1      failure         -1.8
# 1   may         thu  ...         2    999         0  nonexistent          1.1
# 2   may         fri  ...         1    999         1      failure         -1.8
# 3   jun         fri  ...         4    999         0  nonexistent          1.4
# 4   jul         fri  ...         2    999         0  nonexistent          1.4
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          92.893          -46.2      1.299       5099.1  no
# 1          93.994          -36.4      4.860       5191.0  no
# 2          92.893          -46.2      1.313       5099.1  no
# 3          94.465          -41.8      4.967       5228.1  no
# 4          93.918          -42.7      4.963       5228.1  no
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Train
# This creates a general AutoML settings object.
# **Udacity notes:** These inputs must match what was used when training in the portal. `label_column_name` has to be `y` for example.

# %%
automl_settings = {
    "experiment_timeout_minutes": 20,
    "max_concurrent_iterations": 5,
    "primary_metric" : 'AUC_weighted'
}
automl_config = AutoMLConfig(compute_target=compute_target,
                             task = "classification",
                             training_data=dataset,
                             label_column_name="y",   
                             path = project_folder,
                             enable_early_stopping= True,
                             featurization= 'auto',
                             debug_log = "automl_errors.log",
                             
                             **automl_settings
                            )

# %% [markdown]
# #### Create Pipeline and AutoMLStep
#
# You can define outputs for the AutoMLStep using TrainingOutput.

# %%
from azureml.pipeline.core import PipelineData, TrainingOutput

ds = ws.get_default_datastore()
metrics_output_name = 'metrics_output'
best_model_output_name = 'best_model_output'

metrics_data = PipelineData(name='metrics_data',
                           datastore=ds,
                           pipeline_output_name=metrics_output_name,
                           training_output=TrainingOutput(type='Metrics'))
model_data = PipelineData(name='model_data',
                           datastore=ds,
                           pipeline_output_name=best_model_output_name,
                           training_output=TrainingOutput(type='Model'))

# %% [markdown]
# Create an AutoMLStep.

# %%
automl_step = AutoMLStep(
    name='automl_module',
    automl_config=automl_config,
    outputs=[metrics_data, model_data],
    allow_reuse=True)

# %%
from azureml.pipeline.core import Pipeline
pipeline = Pipeline(
    description="pipeline_with_automlstep",
    workspace=ws,    
    steps=[automl_step])

# %%
pipeline_run = experiment.submit(pipeline)
# Out:
# Created step automl_module [e39f1de8][88fdf9b4-1df7-4af9-8e9c-7649937f8533], (This step is eligible to reuse a previous run's output)
# Submitted PipelineRun e8b6e5c8-36f2-46a2-8bcf-da45def6a938
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/automl/runs/e8b6e5c8-36f2-46a2-8bcf-da45def6a938?wsid=/subscriptions/572f8abf-a1a0-4b78-8c6d-3630739c72b5/resourcegroups/aml-quickstarts-123382/workspaces/quick-starts-ws-123382

# %%
from azureml.widgets import RunDetails
RunDetails(pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %%
pipeline_run.wait_for_completion()
# Out:
# PipelineRunId: e8b6e5c8-36f2-46a2-8bcf-da45def6a938
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/automl/runs/e8b6e5c8-36f2-46a2-8bcf-da45def6a938?wsid=/subscriptions/572f8abf-a1a0-4b78-8c6d-3630739c72b5/resourcegroups/aml-quickstarts-123382/workspaces/quick-starts-ws-123382
# PipelineRun Status: Running
#
#
# StepRunId: 49073b3d-26bf-4c9f-b241-79bf6d6e3a8f
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/automl/runs/49073b3d-26bf-4c9f-b241-79bf6d6e3a8f?wsid=/subscriptions/572f8abf-a1a0-4b78-8c6d-3630739c72b5/resourcegroups/aml-quickstarts-123382/workspaces/quick-starts-ws-123382
# StepRun( automl_module ) Status: Running
# WARNING - Retrying (Retry(total=2, connect=3, read=2, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='southcentralus.experiments.azureml.net', port=443): Read timed out. (read timeout=100)",)': /history/v1.0/subscriptions/572f8abf-a1a0-4b78-8c6d-3630739c72b5/resourceGroups/aml-quickstarts-123382/providers/Microsoft.MachineLearningServices/workspaces/quick-starts-ws-123382/experiments/automl/runs/49073b3d-26bf-4c9f-b241-79bf6d6e3a8f/details
# StepRun(automl_module) Execution Summary
# =========================================
# StepRun( automl_module ) Status: Finished
# {'runId': '49073b3d-26bf-4c9f-b241-79bf6d6e3a8f', 'target': 'auto-ml', 'status': 'Completed', 'startTimeUtc': '2020-10-28T13:46:01.686655Z', 'endTimeUtc': '2020-10-28T14:08:51.331204Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': 'e911315f-605c-40c2-9480-69c9d9c06839', 'StepType': 'AutoMLStep', 'azureml.moduleid': '88fdf9b4-1df7-4af9-8e9c-7649937f8533', 'azureml.nodeid': 'e39f1de8', 'azureml.pipelinerunid': 'e8b6e5c8-36f2-46a2-8bcf-da45def6a938', 'num_iterations': '1000', 'training_type': 'TrainFull', 'acquisition_function': 'EI', 'metrics': 'accuracy', 'primary_metric': 'AUC_weighted', 'train_split': '0', 'MaxTimeSeconds': None, 'acquisition_parameter': '0', 'num_cross_validation': None, 'target': 'auto-ml', 'RawAMLSettingsString': None, 'AMLSettingsJsonString': '{"path": null, "name": "placeholder", "subscription_id": "572f8abf-a1a0-4b78-8c6d-3630739c72b5", "resource_group": "aml-quickstarts-123382", "workspace_name": "quick-starts-ws-123382", "region": "southcentralus", "compute_target": null, "spark_service": null, "azure_service": null, "_local_managed_run_id": null, "many_models": false, "iterations": 1000, "primary_metric": "AUC_weighted", "task_type": "classification", "data_script": null, "validation_size": 0.0, "n_cross_validations": null, "y_min": null, "y_max": null, "num_classes": null, "featurization": "auto", "_ignore_package_version_incompatibilities": false, "is_timeseries": false, "max_cores_per_iteration": 1, "max_concurrent_iterations": 5, "iteration_timeout_minutes": null, "mem_in_mb": null, "enforce_time_on_windows": false, "experiment_timeout_minutes": 20, "experiment_exit_score": null, "whitelist_models": null, "blacklist_algos": null, "supported_models": ["MultinomialNaiveBayes", "ExtremeRandomTrees", "XGBoostClassifier", "TensorFlowDNN", "GradientBoosting", "TensorFlowLinearClassifier", "SGD", "LogisticRegression", "LinearSVM", "DecisionTree", "AveragedPerceptronClassifier", "LightGBM", "BernoulliNaiveBayes", "RandomForest", "SVM", "KNN"], "auto_blacklist": true, "blacklist_samples_reached": false, "exclude_nan_labels": true, "verbosity": 20, "_debug_log": "automl_errors.log", "show_warnings": false, "model_explainability": true, "service_url": null, "sdk_url": null, "sdk_packages": null, "enable_onnx_compatible_models": false, "enable_split_onnx_featurizer_estimator_models": false, "vm_type": "STANDARD_D2_V2", "telemetry_verbosity": 20, "send_telemetry": true, "enable_dnn": false, "force_text_dnn": false, "enable_feature_sweeping": true, "enable_early_stopping": true, "early_stopping_n_iters": 10, "metrics": null, "enable_ensembling": true, "enable_stack_ensembling": true, "ensemble_iterations": 15, "enable_tf": false, "enable_subsampling": null, "subsample_seed": null, "enable_nimbusml": false, "enable_streaming": false, "force_streaming": false, "track_child_runs": true, "label_column_name": "y", "weight_column_name": null, "cv_split_column_names": null, "enable_local_managed": false, "cost_mode": 1, "lag_length": 0, "metric_operation": "maximize", "preprocess": true, "scenario": "SDK-1.13.0"}', 'DataPrepJsonString': '{\\"training_data\\": {\\"datasetId\\": \\"31ef439e-4b9e-42d0-baf1-49d34546ee93\\"}, \\"datasets\\": 0}', 'EnableSubsampling': 'False', 'runTemplate': 'AutoML', 'Orchestrator': 'automl', 'ClientType': 'Others', '_aml_system_scenario_identification': 'Remote.Parent', 'root_attribution': 'azureml.StepRun', 'snapshotId': 'e911315f-605c-40c2-9480-69c9d9c06839', 'SetupRunId': '49073b3d-26bf-4c9f-b241-79bf6d6e3a8f_setup', 'SetupRunContainerId': 'dcid.49073b3d-26bf-4c9f-b241-79bf6d6e3a8f_setup', 'ClientSdkVersion': '1.15.0', 'FeaturizationRunJsonPath': 'featurizer_container.json', 'FeaturizationRunId': '49073b3d-26bf-4c9f-b241-79bf6d6e3a8f_featurize', 'ProblemInfoJsonString': '{"dataset_num_categorical": 0, "is_sparse": true, "subsampling": false, "dataset_classes": 2, "dataset_features": 132, "dataset_samples": 29655, "single_frequency_class_detected": false} ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'e8b6e5c8-36f2-46a2-8bcf-da45def6a938', 'status': 'Completed', 'startTimeUtc': '2020-10-28T13:45:22.484089Z', 'endTimeUtc': '2020-10-28T14:13:14.449326Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlstrg123382.blob.core.windows.net/azureml/ExperimentRun/dcid.e8b6e5c8-36f2-46a2-8bcf-da45def6a938/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=B%2FxMLK5JkPIDW0eifIKR2scypCUiuwFaFJ7sL5gSsc0%3D&st=2020-10-28T13%3A35%3A37Z&se=2020-10-28T21%3A45%3A37Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlstrg123382.blob.core.windows.net/azureml/ExperimentRun/dcid.e8b6e5c8-36f2-46a2-8bcf-da45def6a938/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=a4e6599kb%2FQffYP6EGzMjFM3Uh4jHHZcqZD3KX54gUw%3D&st=2020-10-28T13%3A35%3A38Z&se=2020-10-28T21%3A45%3A38Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlstrg123382.blob.core.windows.net/azureml/ExperimentRun/dcid.e8b6e5c8-36f2-46a2-8bcf-da45def6a938/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=9qrmi6SsN36HmkirOKOdhxSbQBCzsGNb9ySRIXv4sCc%3D&st=2020-10-28T13%3A35%3A38Z&se=2020-10-28T21%3A45%3A38Z&sp=r'}}
# 'Finished'

# %% [markdown]
# ## Examine Results
#
# ### Retrieve the metrics of all child runs
# Outputs of above run can be used as inputs of other steps in pipeline. In this tutorial, we will examine the outputs by retrieve output data and running some tests.

# %%
metrics_output = pipeline_run.get_pipeline_output(metrics_output_name)
num_file_downloaded = metrics_output.download('.', show_progress=True)
# Out:
# WARNING - Path already exists. Skipping download for ./azureml/49073b3d-26bf-4c9f-b241-79bf6d6e3a8f/metrics_data

# %%
import json
with open(metrics_output._path_on_datastore) as f:
    metrics_output_result = f.read()
    
deserialized_metrics_output = json.loads(metrics_output_result)
df = pd.DataFrame(deserialized_metrics_output)
df
# Out:
#                                  49073b3d-26bf-4c9f-b241-79bf6d6e3a8f_10  \
# matthews_correlation                                               [0.0]
# f1_score_micro                                      [0.8880121396054628]
# AUC_micro                                            [0.962793490850394]
# recall_score_micro                                  [0.8880121396054628]
# average_precision_score_weighted                     [0.917335305505227]
# average_precision_score_micro                       [0.9643708790304856]
# precision_score_micro                               [0.8880121396054628]
# norm_macro_recall                                                  [0.0]
# balanced_accuracy                                                  [0.5]
# weighted_accuracy                                   [0.9843450583187134]
# precision_score_macro                               [0.4440060698027314]
# average_precision_score_macro                       [0.6895753517121739]
# f1_score_macro                                      [0.4703423886834914]
# precision_score_weighted                             [0.788565560086672]
# recall_score_weighted                               [0.8880121396054628]
# accuracy                                            [0.8880121396054628]
# log_loss                                            [0.2756784987128053]
# AUC_macro                                           [0.8759875483238768]
# f1_score_weighted                                   [0.8353395018439429]
# recall_score_macro                                                 [0.5]
# AUC_weighted                                        [0.8759875483238769]
#
#                                  49073b3d-26bf-4c9f-b241-79bf6d6e3a8f_24  \
# matthews_correlation                               [0.19213028725485287]
# f1_score_micro                                      [0.8849772382397572]
# AUC_micro                                           [0.9499816017739667]
# recall_score_micro                                  [0.8849772382397572]
# average_precision_score_weighted                    [0.9057209447913185]
# average_precision_score_micro                       [0.9460122728123725]
# precision_score_micro                               [0.8849772382397572]
# norm_macro_recall                                  [0.10552249063160479]
# balanced_accuracy                                   [0.5527612453158024]
# weighted_accuracy                                   [0.9674574829922197]
# precision_score_macro                               [0.6749108036575107]
# average_precision_score_macro                       [0.6643536915921682]
# f1_score_macro                                      [0.5666954309243181]
# precision_score_weighted                            [0.8486862398357069]
# recall_score_weighted                               [0.8849772382397572]
# accuracy                                            [0.8849772382397572]
# log_loss                                            [0.2996129005687208]
# AUC_macro                                           [0.8328294868731325]
# f1_score_weighted                                   [0.8548847302534887]
# recall_score_macro                                  [0.5527612453158024]
# AUC_weighted                                        [0.8328294868731326]
#
#                                  49073b3d-26bf-4c9f-b241-79bf6d6e3a8f_21  \
# matthews_correlation                               [0.30126414549106134]
# f1_score_micro                                      [0.7122913505311077]
# AUC_micro                                           [0.8247074129423116]
# recall_score_micro                                  [0.7122913505311077]
# average_precision_score_weighted                    [0.9164490175554443]
# average_precision_score_micro                       [0.7861266503993415]
# precision_score_micro                               [0.7122913505311077]
# norm_macro_recall                                  [0.45339142386639164]
# balanced_accuracy                                   [0.7266957119331958]
# weighted_accuracy                                   [0.7087151372263525]
# precision_score_macro                               [0.6000902096741083]
# average_precision_score_macro                       [0.7054473114395903]
# f1_score_macro                                      [0.5904909085379092]
# precision_score_weighted                            [0.8767520391546748]
# recall_score_weighted                               [0.7122913505311077]
# accuracy                                            [0.7122913505311077]
# log_loss                                            [0.5371450362437541]
# AUC_macro                                           [0.8502909157594651]
# f1_score_weighted                                   [0.7638040583301233]
# recall_score_macro                                  [0.7266957119331958]
# AUC_weighted                                        [0.8502909157594651]
#
#                                  49073b3d-26bf-4c9f-b241-79bf6d6e3a8f_30  \
# matthews_correlation                                [0.3187183462199802]
# f1_score_micro                                      [0.9007587253414264]
# AUC_micro                                           [0.9737530308717166]
# recall_score_micro                                  [0.9007587253414264]
# average_precision_score_weighted                    [0.9470311070568083]
# average_precision_score_micro                       [0.9747660084035891]
# precision_score_micro                               [0.9007587253414264]
# norm_macro_recall                                    [0.135135510616897]
# balanced_accuracy                                   [0.5675677553084485]
# weighted_accuracy                                   [0.9834810305373748]
# precision_score_macro                               [0.8758500772797526]
# average_precision_score_macro                       [0.7969693494944702]
# f1_score_macro                                      [0.5923432191895104]
# precision_score_weighted                            [0.8959103648683194]
# recall_score_weighted                               [0.9007587253414264]
# accuracy                                            [0.9007587253414264]
# log_loss                                            [0.2292238675952688]
# AUC_macro                                           [0.9281958591971429]
# f1_score_weighted                                   [0.8675066697235122]
# recall_score_macro                                  [0.5675677553084485]
# AUC_weighted                                        [0.9281958591971429]
#
#                                  49073b3d-26bf-4c9f-b241-79bf6d6e3a8f_4  \
# matthews_correlation                               [0.4242602566058794]
# f1_score_micro                                     [0.8992412746585736]
# AUC_micro                                          [0.9667522180339456]
# recall_score_micro                                 [0.8992412746585736]
# average_precision_score_weighted                   [0.9367113606803918]
# average_precision_score_micro                      [0.9649885989589592]
# precision_score_micro                              [0.8992412746585736]
# norm_macro_recall                                  [0.3607799987774314]
# balanced_accuracy                                  [0.6803899993887157]
# weighted_accuracy                                  [0.9535761264812502]
# precision_score_macro                               [0.749455022375462]
# average_precision_score_macro                      [0.7581521213108293]
# f1_score_macro                                     [0.7069906124714206]
# precision_score_weighted                           [0.8871765064056368]
# recall_score_weighted                              [0.8992412746585736]
# accuracy                                           [0.8992412746585736]
# log_loss                                          [0.33019342068966073]
# AUC_macro                                          [0.9152213497528003]
# f1_score_weighted                                  [0.8911738058818927]
# recall_score_macro                                 [0.6803899993887157]
# AUC_weighted                                       [0.9152213497528002]
#
#                                  49073b3d-26bf-4c9f-b241-79bf6d6e3a8f_9  \
# matthews_correlation                               [0.3423341743879814]
# f1_score_micro                                     [0.9007587253414264]
# AUC_micro                                          [0.9696925262675549]
# recall_score_micro                                 [0.9007587253414264]
# average_precision_score_weighted                   [0.9365876152338687]
# average_precision_score_micro                       [0.970131337440852]
# precision_score_micro                              [0.9007587253414264]
# norm_macro_recall                                 [0.19671036423282895]
# balanced_accuracy                                  [0.5983551821164145]
# weighted_accuracy                                  [0.9758373452467607]
# precision_score_macro                              [0.7978813226515866]
# average_precision_score_macro                      [0.7647192433761401]
# f1_score_macro                                     [0.6333193689553159]
# precision_score_weighted                           [0.8835399090006326]
# recall_score_weighted                              [0.9007587253414264]
# accuracy                                           [0.9007587253414264]
# log_loss                                           [0.2546401645784923]
# AUC_macro                                          [0.9054445055728753]
# f1_score_weighted                                  [0.8763337379245003]
# recall_score_macro                                 [0.5983551821164145]
# AUC_weighted                                       [0.9054445055728754]
#
#                                  49073b3d-26bf-4c9f-b241-79bf6d6e3a8f_8  \
# matthews_correlation                              [0.06939738570480868]
# f1_score_micro                                      [0.888619119878604]
# AUC_micro                                          [0.9691000066777041]
# recall_score_micro                                  [0.888619119878604]
# average_precision_score_weighted                   [0.9367397767241994]
# average_precision_score_micro                      [0.9699563807281252]
# precision_score_micro                               [0.888619119878604]
# norm_macro_recall                                [0.005420054200542035]
# balanced_accuracy                                   [0.502710027100271]
# weighted_accuracy                                  [0.9844299089511326]
# precision_score_macro                              [0.9442757364105678]
# average_precision_score_macro                      [0.7631688200727385]
# f1_score_macro                                     [0.4758844840760577]
# precision_score_weighted                           [0.9010323549240192]
# recall_score_weighted                               [0.888619119878604]
# accuracy                                            [0.888619119878604]
# log_loss                                            [0.250546570479711]
# AUC_macro                                          [0.9076937539710326]
# f1_score_weighted                                  [0.8368155592289684]
# recall_score_macro                                  [0.502710027100271]
# AUC_weighted                                       [0.9076937539710325]
#
#                                  49073b3d-26bf-4c9f-b241-79bf6d6e3a8f_6  \
# matthews_correlation                              [0.31999379338174755]
# f1_score_micro                                     [0.8977238239757208]
# AUC_micro                                          [0.9682132075775822]
# recall_score_micro                                 [0.8977238239757208]
# average_precision_score_weighted                    [0.931154440957946]
# average_precision_score_micro                       [0.968745047315861]
# precision_score_micro                              [0.8977238239757208]
# norm_macro_recall                                 [0.18855620203502088]
# balanced_accuracy                                  [0.5942781010175104]
# weighted_accuracy                                  [0.9730611889183236]
# precision_score_macro                               [0.771526544069397]
# average_precision_score_macro                      [0.7406590779297226]
# f1_score_macro                                     [0.6263947343363969]
# precision_score_weighted                            [0.877014103638037]
# recall_score_weighted                              [0.8977238239757208]
# accuracy                                           [0.8977238239757208]
# log_loss                                            [0.241787103158241]
# AUC_macro                                          [0.9015577561790655]
# f1_score_weighted                                  [0.8734704046383025]
# recall_score_macro                                 [0.5942781010175104]
# AUC_weighted                                       [0.9015577561790656]
#
#                                  49073b3d-26bf-4c9f-b241-79bf6d6e3a8f_22  \
# matthews_correlation                               [0.33086374333418506]
# f1_score_micro                                      [0.7550834597875569]
# AUC_micro                                           [0.8331590836347895]
# recall_score_micro                                  [0.7550834597875569]
# average_precision_score_weighted                    [0.9124135874969997]
# average_precision_score_micro                       [0.8049532742951484]
# precision_score_micro                               [0.7550834597875569]
# norm_macro_recall                                  [0.47789744131207534]
# balanced_accuracy                                   [0.7389487206560377]
# weighted_accuracy                                   [0.7590892790766044]
# precision_score_macro                               [0.6145337965741724]
# average_precision_score_macro                       [0.7136457101843094]
# f1_score_macro                                      [0.6213916868531584]
# precision_score_weighted                            [0.8789822798976634]
# recall_score_weighted                               [0.7550834597875569]
# accuracy                                            [0.7550834597875569]
# log_loss                                            [0.5637268741440148]
# AUC_macro                                           [0.8277822234818383]
# f1_score_weighted                                   [0.7959830369007871]
# recall_score_macro                                  [0.7389487206560377]
# AUC_weighted                                        [0.8277822234818383]
#
#                                  49073b3d-26bf-4c9f-b241-79bf6d6e3a8f_13  ...  \
# matthews_correlation                               [0.43324348427327514]  ...
# f1_score_micro                                       [0.775720789074355]  ...
# AUC_micro                                           [0.8683231364024676]  ...
# recall_score_micro                                   [0.775720789074355]  ...
# average_precision_score_weighted                     [0.931778973814178]  ...
# average_precision_score_micro                       [0.8685942654415846]  ...
# precision_score_micro                                [0.775720789074355]  ...
# norm_macro_recall                                   [0.6337601209231503]  ...
# balanced_accuracy                                   [0.8168800604615751]  ...
# weighted_accuracy                                    [0.765502055328361]  ...
# precision_score_macro                               [0.6480843543704197]  ...
# average_precision_score_macro                       [0.7475519577967901]  ...
# f1_score_macro                                      [0.6615053403504685]  ...
# precision_score_weighted                            [0.9048635546363228]  ...
# recall_score_weighted                                [0.775720789074355]  ...
# accuracy                                             [0.775720789074355]  ...
# log_loss                                            [0.5714706825564349]  ...
# AUC_macro                                           [0.8903226284484308]  ...
# f1_score_weighted                                   [0.8140909737814915]  ...
# recall_score_macro                                  [0.8168800604615751]  ...
# AUC_weighted                                        [0.8903226284484309]  ...
#
#                                  49073b3d-26bf-4c9f-b241-79bf6d6e3a8f_17  \
# matthews_correlation                                [0.3550682161394279]
# f1_score_micro                                      [0.8971168437025797]
# AUC_micro                                           [0.9685395400673757]
# recall_score_micro                                  [0.8971168437025797]
# average_precision_score_weighted                    [0.9325169857810648]
# average_precision_score_micro                       [0.9696026940179299]
# precision_score_micro                               [0.8971168437025797]
# norm_macro_recall                                  [0.25181579225224926]
# balanced_accuracy                                   [0.6259078961261246]
# weighted_accuracy                                    [0.964450689307912]
# precision_score_macro                               [0.7503286965937088]
# average_precision_score_macro                       [0.7457484284043038]
# f1_score_macro                                      [0.6598148755558438]
# precision_score_weighted                            [0.8776911981740897]
# recall_score_weighted                               [0.8971168437025797]
# accuracy                                            [0.8971168437025797]
# log_loss                                           [0.23591104100781143]
# AUC_macro                                           [0.9020602133567475]
# f1_score_weighted                                   [0.8803022056979963]
# recall_score_macro                                  [0.6259078961261246]
# AUC_weighted                                        [0.9020602133567475]
#
#                                  49073b3d-26bf-4c9f-b241-79bf6d6e3a8f_0  \
# matthews_correlation                               [0.5323740218566827]
# f1_score_micro                                     [0.9116843702579667]
# AUC_micro                                           [0.979695082216353]
# recall_score_micro                                 [0.9116843702579667]
# average_precision_score_weighted                   [0.9531771295804466]
# average_precision_score_micro                      [0.9806603102489483]
# precision_score_micro                              [0.9116843702579667]
# norm_macro_recall                                  [0.5026785366965085]
# balanced_accuracy                                  [0.7513392683482543]
# weighted_accuracy                                  [0.9514937218005303]
# precision_score_macro                              [0.7819118765348991]
# average_precision_score_macro                      [0.8151093723721079]
# f1_score_macro                                     [0.7653697272147331]
# precision_score_weighted                           [0.9072720074188747]
# recall_score_weighted                              [0.9116843702579667]
# accuracy                                           [0.9116843702579667]
# log_loss                                          [0.17775706110025447]
# AUC_macro                                          [0.9450464668693166]
# f1_score_weighted                                  [0.9091539479147899]
# recall_score_macro                                 [0.7513392683482543]
# AUC_weighted                                       [0.9450464668693167]
#
#                                  49073b3d-26bf-4c9f-b241-79bf6d6e3a8f_19  \
# matthews_correlation                                               [0.0]
# f1_score_micro                                      [0.8880121396054628]
# AUC_micro                                            [0.962565435743217]
# recall_score_micro                                  [0.8880121396054628]
# average_precision_score_weighted                     [0.920082037392781]
# average_precision_score_micro                       [0.9637332763142692]
# precision_score_micro                               [0.8880121396054628]
# norm_macro_recall                                                  [0.0]
# balanced_accuracy                                                  [0.5]
# weighted_accuracy                                   [0.9843450583187134]
# precision_score_macro                               [0.4440060698027314]
# average_precision_score_macro                       [0.7043099631178652]
# f1_score_macro                                      [0.4703423886834914]
# precision_score_weighted                             [0.788565560086672]
# recall_score_weighted                               [0.8880121396054628]
# accuracy                                            [0.8880121396054628]
# log_loss                                           [0.28620755426275074]
# AUC_macro                                           [0.8748409271515819]
# f1_score_weighted                                   [0.8353395018439429]
# recall_score_macro                                                 [0.5]
# AUC_weighted                                        [0.8748409271515819]
#
#                                  49073b3d-26bf-4c9f-b241-79bf6d6e3a8f_2  \
# matthews_correlation                              [0.20174105790449157]
# f1_score_micro                                     [0.8931714719271624]
# AUC_micro                                          [0.9702536376217242]
# recall_score_micro                                 [0.8931714719271624]
# average_precision_score_weighted                   [0.9392757658662093]
# average_precision_score_micro                      [0.9715388741657829]
# precision_score_micro                              [0.8931714719271624]
# norm_macro_recall                                 [0.04843872430521978]
# balanced_accuracy                                  [0.5242193621526099]
# weighted_accuracy                                  [0.9847723007984813]
# precision_score_macro                              [0.9201127819548872]
# average_precision_score_macro                      [0.7693722267966688]
# f1_score_macro                                      [0.518013809978158]
# precision_score_weighted                           [0.8989617442696269]
# recall_score_weighted                              [0.8931714719271624]
# accuracy                                           [0.8931714719271624]
# log_loss                                           [0.2318257052236167]
# AUC_macro                                            [0.91312399624338]
# f1_score_weighted                                  [0.8480028507774715]
# recall_score_macro                                 [0.5242193621526099]
# AUC_weighted                                       [0.9131239962433799]
#
#                                  49073b3d-26bf-4c9f-b241-79bf6d6e3a8f_11  \
# matthews_correlation                                [0.5463263672625905]
# f1_score_micro                                      [0.8804248861911987]
# AUC_micro                                            [0.943773915966851]
# recall_score_micro                                  [0.8804248861911987]
# average_precision_score_weighted                    [0.9376764875516017]
# average_precision_score_micro                       [0.9369080696457877]
# precision_score_micro                               [0.8804248861911987]
# norm_macro_recall                                   [0.6664110386831825]
# balanced_accuracy                                   [0.8332055193415913]
# weighted_accuracy                                   [0.8921481777176951]
# precision_score_macro                               [0.7239402427637722]
# average_precision_score_macro                       [0.7561679653694633]
# f1_score_macro                                      [0.7606271563709098]
# precision_score_weighted                            [0.9140263393167081]
# recall_score_weighted                               [0.8804248861911987]
# accuracy                                            [0.8804248861911987]
# log_loss                                            [0.6218514320905204]
# AUC_macro                                           [0.9239127011912635]
# f1_score_weighted                                   [0.8920397669030757]
# recall_score_macro                                  [0.8332055193415913]
# AUC_weighted                                        [0.9239127011912635]
#
#                                  49073b3d-26bf-4c9f-b241-79bf6d6e3a8f_37  \
# matthews_correlation                                [0.5297670078987109]
# f1_score_micro                                      [0.9132018209408195]
# AUC_micro                                           [0.9798554392202284]
# recall_score_micro                                  [0.9132018209408195]
# average_precision_score_weighted                    [0.9540219726768622]
# average_precision_score_micro                       [0.9808010304795092]
# precision_score_micro                               [0.9132018209408195]
# norm_macro_recall                                   [0.4854412453898975]
# balanced_accuracy                                   [0.7427206226949488]
# weighted_accuracy                                   [0.9555276910268847]
# precision_score_macro                               [0.7890700834789361]
# average_precision_score_macro                       [0.8189124222511974]
# f1_score_macro                                      [0.7630388121791467]
# precision_score_weighted                            [0.9071083328988081]
# recall_score_weighted                               [0.9132018209408195]
# accuracy                                            [0.9132018209408195]
# log_loss                                            [0.1972469481821191]
# AUC_macro                                           [0.9451779856144426]
# f1_score_weighted                                   [0.9094234150779638]
# recall_score_macro                                  [0.7427206226949488]
# AUC_weighted                                        [0.9451779856144426]
#
#                                  49073b3d-26bf-4c9f-b241-79bf6d6e3a8f_3  \
# matthews_correlation                               [0.5351653240994095]
# f1_score_micro                                     [0.8603945371775417]
# AUC_micro                                          [0.9265084127557963]
# recall_score_micro                                 [0.8603945371775418]
# average_precision_score_weighted                   [0.9374598210249693]
# average_precision_score_micro                      [0.9090167240315753]
# precision_score_micro                              [0.8603945371775418]
# norm_macro_recall                                  [0.6959564469192197]
# balanced_accuracy                                  [0.8479782234596098]
# weighted_accuracy                                   [0.863477172018101]
# precision_score_macro                              [0.7057613844847888]
# average_precision_score_macro                      [0.7582307709124276]
# f1_score_macro                                     [0.7441504180153756]
# precision_score_weighted                           [0.9155210510287511]
# recall_score_weighted                              [0.8603945371775418]
# accuracy                                           [0.8603945371775418]
# log_loss                                           [0.3547586532266784]
# AUC_macro                                          [0.9186065681572742]
# f1_score_weighted                                  [0.8779803201755102]
# recall_score_macro                                 [0.8479782234596098]
# AUC_weighted                                       [0.9186065681572742]
#
#                                  49073b3d-26bf-4c9f-b241-79bf6d6e3a8f_26  \
# matthews_correlation                                [0.4200301869901809]
# f1_score_micro                                      [0.8974203338391502]
# AUC_micro                                           [0.9669760362530251]
# recall_score_micro                                  [0.8974203338391502]
# average_precision_score_weighted                    [0.9413414198614478]
# average_precision_score_micro                       [0.9638940116268354]
# precision_score_micro                               [0.8974203338391502]
# norm_macro_recall                                   [0.3634659449807076]
# balanced_accuracy                                   [0.6817329724903538]
# weighted_accuracy                                   [0.9509696714176505]
# precision_score_macro                               [0.7426986082456375]
# average_precision_score_macro                       [0.7727465296167129]
# f1_score_macro                                      [0.7058924500837659]
# precision_score_weighted                            [0.8859885221690754]
# recall_score_weighted                               [0.8974203338391502]
# accuracy                                            [0.8974203338391502]
# log_loss                                           [0.33856551650868877]
# AUC_macro                                           [0.9232023147299142]
# f1_score_weighted                                   [0.8900732694754612]
# recall_score_macro                                  [0.6817329724903538]
# AUC_weighted                                        [0.9232023147299142]
#
#                                  49073b3d-26bf-4c9f-b241-79bf6d6e3a8f_7  \
# matthews_correlation                               [0.4649813590296837]
# f1_score_micro                                     [0.8983308042488619]
# AUC_micro                                          [0.9652476622279123]
# recall_score_micro                                 [0.8983308042488619]
# average_precision_score_weighted                   [0.9371290250854898]
# average_precision_score_micro                      [0.9565307880327896]
# precision_score_micro                              [0.8983308042488619]
# norm_macro_recall                                 [0.44264393429990356]
# balanced_accuracy                                  [0.7213219671499518]
# weighted_accuracy                                  [0.9422773104924936]
# precision_score_macro                              [0.7442230057744392]
# average_precision_score_macro                      [0.7544189868217579]
# f1_score_macro                                     [0.7319387567514666]
# precision_score_weighted                            [0.893768979474287]
# recall_score_weighted                              [0.8983308042488619]
# accuracy                                           [0.8983308042488619]
# log_loss                                           [0.2453472030717318]
# AUC_macro                                          [0.9224511759813429]
# f1_score_weighted                                   [0.895831077803408]
# recall_score_macro                                 [0.7213219671499518]
# AUC_weighted                                       [0.9224511759813429]
#
#                                  49073b3d-26bf-4c9f-b241-79bf6d6e3a8f_12
# matthews_correlation                               [0.34546286432025275]
# f1_score_micro                                      [0.8992412746585736]
# AUC_micro                                            [0.972064723071007]
# recall_score_micro                                  [0.8992412746585736]
# average_precision_score_weighted                    [0.9393307402215808]
# average_precision_score_micro                       [0.9727752648265704]
# precision_score_micro                               [0.8992412746585736]
# norm_macro_recall                                  [0.21868418274066537]
# balanced_accuracy                                   [0.6093420913703327]
# weighted_accuracy                                   [0.9712154002288209]
# precision_score_macro                               [0.7728697364589063]
# average_precision_score_macro                       [0.7684898552488926]
# f1_score_macro                                      [0.6446520777624456]
# precision_score_weighted                            [0.8798316772654436]
# recall_score_weighted                               [0.8992412746585736]
# accuracy                                            [0.8992412746585736]
# log_loss                                           [0.23444060577283457]
# AUC_macro                                           [0.9165809942446655]
# f1_score_weighted                                   [0.8780635429698314]
# recall_score_macro                                  [0.6093420913703327]
# AUC_weighted                                        [0.9165809942446657]
#
# [21 rows x 37 columns]

# %% [markdown]
# ### Retrieve the Best Model

# %%
# Retrieve best model from Pipeline Run
best_model_output = pipeline_run.get_pipeline_output(best_model_output_name)
num_file_downloaded = best_model_output.download('.', show_progress=True)
# Out:
# Downloading azureml/49073b3d-26bf-4c9f-b241-79bf6d6e3a8f/model_data
# Downloaded azureml/49073b3d-26bf-4c9f-b241-79bf6d6e3a8f/model_data, 1 files out of an estimated total of 1

# %%
import pickle

with open(best_model_output._path_on_datastore, "rb" ) as f:
    best_model = pickle.load(f)
best_model
# Out:
# PipelineWithYTransformations(Pipeline={'memory': None,
#                                        'steps': [('datatransformer',
#                                                   DataTransformer(enable_dnn=None,
#                                                                   enable_feature_sweeping=None,
#                                                                   feature_sweeping_config=None,
#                                                                   feature_sweeping_timeout=None,
#                                                                   featurization_config=None,
#                                                                   force_text_dnn=None,
#                                                                   is_cross_validation=None,
#                                                                   is_onnx_compatible=None,
#                                                                   logger=None,
#                                                                   observer=None,
#                                                                   task=None,
#                                                                   working_dir=None))...
#                                                                                                                                      min_weight_fraction_leaf=0.0,
#                                                                                                                                      n_estimators=25,
#                                                                                                                                      n_jobs=1,
#                                                                                                                                      oob_score=False,
#                                                                                                                                      random_state=None,
#                                                                                                                                      verbose=0,
#                                                                                                                                      warm_start=False))],
#                                                                                                       verbose=False))],
#                                                                                 flatten_transform=None,
#                                                                                 weights=[0.5333333333333333,
#                                                                                          0.13333333333333333,
#                                                                                          0.06666666666666667,
#                                                                                          0.06666666666666667,
#                                                                                          0.06666666666666667,
#                                                                                          0.06666666666666667,
#                                                                                          0.06666666666666667]))],
#                                        'verbose': False},
#                              y_transformer={},
#                              y_transformer_name='LabelEncoder')

# %%
best_model.steps
# Out:
# [('datatransformer',
#   DataTransformer(enable_dnn=None, enable_feature_sweeping=None,
#                   feature_sweeping_config=None, feature_sweeping_timeout=None,
#                   featurization_config=None, force_text_dnn=None,
#                   is_cross_validation=None, is_onnx_compatible=None, logger=None,
#                   observer=None, task=None, working_dir=None)),
#  ('prefittedsoftvotingclassifier',
#   PreFittedSoftVotingClassifier(classification_labels=None,
#                                 estimators=[('0',
#                                              Pipeline(memory=None,
#                                                       steps=[('maxabsscaler',
#                                                               MaxAbsScaler(copy=True)),
#                                                              ('lightgbmclassifier',
#                                                               LightGBMClassifier(boosting_type='gbdt',
#                                                                                  class_weight=None,
#                                                                                  colsample_bytree=1.0,
#                                                                                  importance_type='split',
#                                                                                  learning_rate=0.1,
#                                                                                  max_depth=-1,
#                                                                                  min_child_samples=20,
#                                                                                  min_child_weight=0.001,
#                                                                                  min_spl...
#                                                                                      min_samples_leaf=0.035789473684210524,
#                                                                                      min_samples_split=0.29105263157894734,
#                                                                                      min_weight_fraction_leaf=0.0,
#                                                                                      n_estimators=25,
#                                                                                      n_jobs=1,
#                                                                                      oob_score=False,
#                                                                                      random_state=None,
#                                                                                      verbose=0,
#                                                                                      warm_start=False))],
#                                                       verbose=False))],
#                                 flatten_transform=None,
#                                 weights=[0.5333333333333333, 0.13333333333333333,
#                                          0.06666666666666667, 0.06666666666666667,
#                                          0.06666666666666667, 0.06666666666666667,
#                                          0.06666666666666667]))]

# %% [markdown]
# ### Test the Model
# #### Load Test Data
# For the test data, it should have the same preparation step as the train data. Otherwise it might get failed at the preprocessing step.

# %%
dataset_test = Dataset.Tabular.from_delimited_files(path='https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv')
df_test = dataset_test.to_pandas_dataframe()
df_test = df_test[pd.notnull(df_test['y'])]

y_test = df_test['y']
X_test = df_test.drop(['y'], axis=1)

# %% [markdown]
# #### Testing Our Best Fitted Model
#
# We will use confusion matrix to see how our model works.

# %%
from sklearn.metrics import confusion_matrix
ypred = best_model.predict(X_test)
cm = confusion_matrix(y_test, ypred)

# %%
# Visualize the confusion matrix
pd.DataFrame(cm).style.background_gradient(cmap='Blues', low=0, high=0.9)
# Out:
# <style  type="text/css" >
#     #T_12c40786_1929_11eb_84bf_acde48001122row0_col0 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }    #T_12c40786_1929_11eb_84bf_acde48001122row0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_12c40786_1929_11eb_84bf_acde48001122row1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_12c40786_1929_11eb_84bf_acde48001122row1_col1 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }</style><table id="T_12c40786_1929_11eb_84bf_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_12c40786_1929_11eb_84bf_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_12c40786_1929_11eb_84bf_acde48001122row0_col0" class="data row0 col0" >28591</td>
#                         <td id="T_12c40786_1929_11eb_84bf_acde48001122row0_col1" class="data row0 col1" >667</td>
#             </tr>
#             <tr>
#                         <th id="T_12c40786_1929_11eb_84bf_acde48001122level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_12c40786_1929_11eb_84bf_acde48001122row1_col0" class="data row1 col0" >1287</td>
#                         <td id="T_12c40786_1929_11eb_84bf_acde48001122row1_col1" class="data row1 col1" >2405</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Publish and run from REST endpoint
#
# Run the following code to publish the pipeline to your workspace. In your workspace in the portal, you can see metadata for the pipeline including run history and durations. You can also run the pipeline manually from the portal.
#
# Additionally, publishing the pipeline enables a REST endpoint to rerun the pipeline from any HTTP library on any platform.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name="Bankmarketing Train", description="Training bankmarketing pipeline", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: Bankmarketing Train,
# Id: ddf6abb6-782a-4d41-8ca1-bdd2ef68e83d,
# Status: Active,
# Endpoint: https://southcentralus.api.azureml.ms/pipelines/v1.0/subscriptions/572f8abf-a1a0-4b78-8c6d-3630739c72b5/resourceGroups/aml-quickstarts-123382/providers/Microsoft.MachineLearningServices/workspaces/quick-starts-ws-123382/PipelineRuns/PipelineSubmit/ddf6abb6-782a-4d41-8ca1-bdd2ef68e83d)

# %% [markdown]
# Authenticate once again, to retrieve the `auth_header` so that the endpoint can be used

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %% [markdown]
# Get the REST url from the endpoint property of the published pipeline object. You can also find the REST url in your workspace in the portal. Build an HTTP POST request to the endpoint, specifying your authentication header. Additionally, add a JSON payload object with the experiment name and the batch size parameter. As a reminder, the process_count_per_node is passed through to ParallelRunStep because you defined it is defined as a PipelineParameter object in the step configuration.
#
# Make the request to trigger the run. Access the Id key from the response dict to get the value of the run id.

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "pipeline-rest-endpoint"}
                        )

# %%
try:
    response.raise_for_status()
except Exception:    
    raise Exception("Received bad response from the endpoint: {}\n"
                    "Response Code: {}\n"
                    "Headers: {}\n"
                    "Content: {}".format(rest_endpoint, response.status_code, response.headers, response.content))

run_id = response.json().get('Id')
print('Submitted pipeline run: ', run_id)
# Out:
# Submitted pipeline run:  aa48e8a8-50da-47a2-98b3-a48d6295547d

# %% [markdown]
# Use the run id to monitor the status of the new run. This will take another 10-15 min to run and will look similar to the previous pipeline run, so if you don't need to see another pipeline run, you can skip watching the full output.

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments["pipeline-rest-endpoint"], run_id)
RunDetails(published_pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %%
from azureml.core import Workspace
from azureml.core.webservice import Webservice


# Set with the deployment name
name = "best-deploy-model"

# load existing web service
service = Webservice(name=name, workspace=ws)
service.update(enable_app_insights=True)

logs = service.get_logs()

for line in logs.split('\n'):
    print(line)
# Out:
# 2020-10-28T15:39:05,858355751+00:00 - iot-server/run
# 2020-10-28T15:39:05,876469835+00:00 - gunicorn/run
# /usr/sbin/nginx: /azureml-envs/azureml_1e04293de403c2a29e0607200eb309aa/lib/libcrypto.so.1.0.0: no version information available (required by /usr/sbin/nginx)
# /usr/sbin/nginx: /azureml-envs/azureml_1e04293de403c2a29e0607200eb309aa/lib/libcrypto.so.1.0.0: no version information available (required by /usr/sbin/nginx)
# /usr/sbin/nginx: /azureml-envs/azureml_1e04293de403c2a29e0607200eb309aa/lib/libssl.so.1.0.0: no version information available (required by /usr/sbin/nginx)
# /usr/sbin/nginx: /azureml-envs/azureml_1e04293de403c2a29e0607200eb309aa/lib/libssl.so.1.0.0: no version information available (required by /usr/sbin/nginx)
# /usr/sbin/nginx: /azureml-envs/azureml_1e04293de403c2a29e0607200eb309aa/lib/libssl.so.1.0.0: no version information available (required by /usr/sbin/nginx)
# 2020-10-28T15:39:05,880169052+00:00 - nginx/run
# 2020-10-28T15:39:05,871570212+00:00 - rsyslog/run
# rsyslogd: /azureml-envs/azureml_1e04293de403c2a29e0607200eb309aa/lib/libuuid.so.1: no version information available (required by rsyslogd)
# EdgeHubConnectionString and IOTEDGE_IOTHUBHOSTNAME are not set. Exiting...
# 2020-10-28T15:39:06,064640304+00:00 - iot-server/finish 1 0
# 2020-10-28T15:39:06,113628131+00:00 - Exit code 1 is normal. Not restarting iot-server.
# Starting gunicorn 19.9.0
# Listening at: http://127.0.0.1:31311 (13)
# Using worker: sync
# worker timeout is set to 300
# Booting worker with pid: 40
# SPARK_HOME not set. Skipping PySpark Initialization.
# Generating new fontManager, this may take some time...
# Initializing logger
# 2020-10-28 15:39:07,832 | root | INFO | Starting up app insights client
# Starting up app insights client
# 2020-10-28 15:39:07,833 | root | INFO | Starting up request id generator
# Starting up request id generator
# 2020-10-28 15:39:07,833 | root | INFO | Starting up app insight hooks
# Starting up app insight hooks
# 2020-10-28 15:39:07,833 | root | INFO | Invoking user's init function
# Invoking user's init function
# 2020-10-28 15:39:09,055 | root | INFO | Users's init has completed successfully
# Users's init has completed successfully
# /azureml-envs/azureml_1e04293de403c2a29e0607200eb309aa/lib/python3.6/site-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)
# /azureml-envs/azureml_1e04293de403c2a29e0607200eb309aa/lib/python3.6/site-packages/numpy/core/numeric.py:2327: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   return bool(asarray(a1 == a2).all())
# 2020-10-28 15:39:09,059 | root | INFO | Skipping middleware: dbg_model_info as it's not enabled.
# Skipping middleware: dbg_model_info as it's not enabled.
# 2020-10-28 15:39:09,059 | root | INFO | Skipping middleware: dbg_resource_usage as it's not enabled.
# Skipping middleware: dbg_resource_usage as it's not enabled.
# 2020-10-28 15:39:09,112 | root | INFO | Scoring timeout is found from os.environ: 60000 ms
# Scoring timeout is found from os.environ: 60000 ms
# 2020-10-28 15:39:10,180 | root | INFO | 200
# 200
# 127.0.0.1 - - [28/Oct/2020:15:39:10 +0000] "GET /swagger.json HTTP/1.0" 200 3208 "-" "Go-http-client/1.1"
# 2020-10-28 15:39:29,192 | root | INFO | 200
# 200
# 127.0.0.1 - - [28/Oct/2020:15:39:29 +0000] "GET /swagger.json HTTP/1.0" 200 3208 "-" "Go-http-client/1.1"
# 2020-10-28 15:39:29,739 | root | INFO | 200
# 200
# 127.0.0.1 - - [28/Oct/2020:15:39:29 +0000] "GET /swagger.json HTTP/1.0" 200 3208 "-" "Go-http-client/1.1"
# 2020-10-28 15:40:10,790 | root | INFO | 200
# 200
# 127.0.0.1 - - [28/Oct/2020:15:40:10 +0000] "GET /swagger.json HTTP/1.0" 200 3208 "-" "Go-http-client/1.1"
# 2020-10-28 15:40:15,788 | root | INFO | 200
# 200
# 127.0.0.1 - - [28/Oct/2020:15:40:15 +0000] "GET /swagger.json HTTP/1.0" 200 3208 "-" "Go-http-client/1.1"
